# %%
from tensorflow.keras.models import Model # Импортируем модели keras: Model
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, Add, MaxPooling2D, Conv2D, BatchNormalization # Импортируем стандартные слои keras
from tensorflow.keras import backend as K # Импортируем модуль backend keras'а
from tensorflow.keras.optimizers import Adam # Импортируем оптимизатор Adam
from tensorflow.keras import utils # Импортируем модуль utils библиотеки tensorflow.keras для получения OHE-представления
import tensorflow as tf
from google.colab import files # Импортируем Модуль files для работы с файлами
import matplotlib.pyplot as plt # Импортируем модуль pyplot библиотеки matplotlib для построения графиков
from tensorflow.keras.preprocessing import image # Импортируем модуль image для работы с изображениями
import numpy as np # Импортируем библиотеку numpy
from sklearn.model_selection import train_test_split
import time
import random
import shutil
import os # Импортируем библиотеку os для раоты с фаловой системой
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os # Импортируем библиотеку os для раоты с фаловой системой
from PIL import Image # импортируем модель Image для работы с изображениями
import seaborn as sns


import numba as nb
import cv2 as cv
from PIL import Image
from numpy.lib.stride_tricks import as_strided
sns.set_style('darkgrid')

# %%
from google.colab import drive # Подключаем гугл-диск
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Глобальные параметры
num_classes = 2 # Задаем количество классов на изображении
directory = '/content/drive/My Drive/segmentation/' # Указываем путь к обучающей выборке с оригинальными изображения

# %%
def order_points(pts):
	# initialzie a list of coordinates that will be ordered
	# such that the first entry in the list is the top-left,
	# the second entry is the top-right, the third is the
	# bottom-right, and the fourth is the bottom-left
	rect = np.zeros((4, 2), dtype = "float32")
	# the top-left point will have the smallest sum, whereas
	# the bottom-right point will have the largest sum
	s = pts.sum(axis = 1)
	rect[0] = pts[np.argmin(s)]
	rect[2] = pts[np.argmax(s)]
	# now, compute the difference between the points, the
	# top-right point will have the smallest difference,
	# whereas the bottom-left will have the largest difference
	diff = np.diff(pts, axis = 1)
	rect[1] = pts[np.argmin(diff)]
	rect[3] = pts[np.argmax(diff)]
	# return the ordered coordinates
	return rect

def four_point_transform(image, pts):
	# obtain a consistent order of the points and unpack them
	# individually
	rect = order_points(pts)
	(tl, tr, br, bl) = rect
	# compute the width of the new image, which will be the
	# maximum distance between bottom-right and bottom-left
	# x-coordiates or the top-right and top-left x-coordinates
	widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
	widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
	maxWidth = max(int(widthA), int(widthB))
	# compute the height of the new image, which will be the
	# maximum distance between the top-right and bottom-right
	# y-coordinates or the top-left and bottom-left y-coordinates
	heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
	heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
	maxHeight = max(int(heightA), int(heightB))
	# now that we have the dimensions of the new image, construct
	# the set of destination points to obtain a "birds eye view",
	# (i.e. top-down view) of the image, again specifying points
	# in the top-left, top-right, bottom-right, and bottom-left
	# order
	dst = np.array([
		[0, 0],
		[maxWidth - 1, 0],
		[maxWidth - 1, maxHeight - 1],
		[0, maxHeight - 1]], dtype = "float32")
	# compute the perspective transform matrix and then apply it
	M = cv.getPerspectiveTransform(rect, dst)
	warped = cv.warpPerspective(image, M, (maxWidth, maxHeight))
	# return the warped image
	return warped

def get_coordinates_logic(img, factor = 100):
  color = (128, 0, 128)
  width = img.shape[1]
  height = img.shape[0]
  x_scale = width - factor + 1
  y_scale = height - factor + 1

  try:
    temp_img = img[0:factor, 0:factor, :]
    w1 = min(np.array(np.where(np.all(temp_img != color, axis=-1)))[1])
    h1 = min(np.array(np.where(np.all(temp_img != color, axis=-1)))[0])
    temp_img = img[0:factor, -factor:, :]
    w2 = max(np.array(np.where(np.all(temp_img != color, axis=-1)))[1]) + x_scale
    h2 = min(np.array(np.where(np.all(temp_img != color, axis=-1)))[0])
    temp_img = img[-factor:, -factor:, :]
    w3 = max(np.array(np.where(np.all(temp_img != color, axis=-1)))[1]) + x_scale
    h3 = max(np.array(np.where(np.all(temp_img != color, axis=-1)))[0]) + y_scale
    temp_img = img[-factor:, 0:factor, :]
    w4 = min(np.array(np.where(np.all(temp_img != color, axis=-1)))[1])
    h4 = max(np.array(np.where(np.all(temp_img != color, axis=-1)))[0]) + y_scale
  except:
    w1, w2, w3, w4, h1, h2, h3, h4 = get_coordinates_logic(img, factor = factor + 50)
  
  return w1, w2, w3, w4, h1, h2, h3, h4

def process_img(img):
  img = img.copy()
  temp = img.copy()
  height = img.shape[0]
  width = img.shape[1]

  itemindex = np.array(np.where(np.all(img == (128, 0, 128), axis=-1)))

  minH = min(itemindex[0]) 
  maxH = max(itemindex[0])
  minW = min(itemindex[1])
  maxW = max(itemindex[1])

  pts = np.float32([[minW,minH],[maxW,minH],[minW,maxH],[maxW,maxH]])
  img_cropped = img[minH:maxH, minW:maxW]

  w1, w2, w3, w4, h1, h2, h3, h4 = get_coordinates_logic(img_cropped)

  result = four_point_transform(img_cropped, np.array([[w1, h1], [w2, h2], [w3, h3], [w4, h4]]))
  return result

def index2color(segment_img, actual_img, color = (128, 0, 128), final_mode = False):
  new_img = np.zeros_like(actual_img)
  segment_img = cv.resize(segment_img, (actual_img.shape[1], actual_img.shape[0]), interpolation = cv.INTER_NEAREST)
  segment_img = np.round(segment_img)

  zero_index = np.where(np.all(segment_img == (1, 0), axis=-1))
  ones_index = np.where(np.all(segment_img == (0, 1), axis=-1))
  
  new_img[zero_index] = (128, 0, 128)
  new_img[ones_index] = actual_img[ones_index]
  
  if final_mode:
    new_img = process_img(new_img)
  new_img[np.where(np.all(new_img == (128, 0, 128), axis=-1))] = (255, 255, 255)
  return new_img

def image_preprocessing(img):
  img = cv.resize(img, (img_height, img_width), interpolation = cv.INTER_NEAREST)

# %%
# Функция перевода индекса пикслея в to_categorical
def rgbToohe(y, num_classes): 
  y2 = y.copy() # Создаем копию входного массива
  y = y.reshape(y.shape[0] * y.shape[1], 3) # Решейпим в двумерный массив
  yt = [] # Создаем пустой лист
  for i in range(len(y)): # Проходим по всем трем канала изображения
    yt.append(utils.to_categorical(color2index(y[i]), num_classes=num_classes)) # Переводим пиксели в индексы и преобразуем в OHE
  yt = np.array(yt) # Преобразуем в numpy
  yt = yt.reshape(y2.shape[0], y2.shape[1], num_classes) # Решейпим к исходныму размеру
  return yt # Возвращаем сформированный массив

# %%
img_width = 512
img_height = 768

# %%
seed = 909 # (IMPORTANT) to transform image and corresponding mask with same augmentation parameter.
image_datagen = ImageDataGenerator(width_shift_range=0.1,
                 height_shift_range=0.1, preprocessing_function = image_preprocessing) # custom fuction for each image you can use resnet one too.
mask_datagen = ImageDataGenerator(width_shift_range=0.1,
                 height_shift_range=0.1,
                 preprocessing_function = rgbToohe)

image_generator = image_datagen.flow_from_directory(directory + '/generator_train/input/',
                                                    class_mode=None, batch_size = 2, seed=seed)

mask_generator = mask_datagen.flow_from_directory(directory + '/generator_train/output/',
                                                   class_mode=None, batch_size = 2, seed=seed)

train_generator = zip(image_generator, mask_generator)
# Out:
# Found 200 images belonging to 1 classes.
# Found 200 images belonging to 1 classes.

# %%
seed = 909 # (IMPORTANT) to transform image and corresponding mask with same augmentation parameter.
image_datagen = ImageDataGenerator(width_shift_range=0.1,
                 height_shift_range=0.1,
                 preprocessing_function = image_preprocessing) # custom fuction for each image you can use resnet one too.
mask_datagen = ImageDataGenerator(width_shift_range=0.1,
                 height_shift_range=0.1,
                 preprocessing_function = rgbToohe)  # to make mask as feedable formate (256,256,1)

image_generator = image_datagen.flow_from_directory(directory + '/generator_test/input/',
                                                    class_mode=None, batch_size = 2, seed=seed)

mask_generator = mask_datagen.flow_from_directory(directory + '/generator_test/output/',
                                                   class_mode=None, batch_size = 2, seed=seed)

test_generator = zip(image_generator, mask_generator)
# Out:
# Found 49 images belonging to 1 classes.
# Found 49 images belonging to 1 classes.

# %%
def dice_coef(y_true, y_pred):
    return (2. * K.sum(y_true * y_pred) + 1.) / (K.sum(y_true) + K.sum(y_pred) + 1.) # Возвращаем площадь пересечения деленную на площадь объединения двух областей

# %%
'''
  Функция создания сети
    Входные параметры:
    - num_classes - количество классов
    - input_shape - размерность карты сегментации
'''
def unetWithMask(num_classes = num_classes, input_shape = (img_width, img_height, 3)):
    img_input = Input(input_shape)                                      # Создаем входной слой с размерностью input_shape

    # Block 1
    x = Conv2D(64, (3, 3), padding='same', name='block1_conv1')(img_input) # Добавляем Conv2D-слой с 64-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv2')(x)      # Добавляем Conv2D-слой с 64-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    block_1_out = Activation('relu')(x)                                 # Добавляем слой Activation и запоминаем в переменной block_1_out
    
    block_1_out_mask = Conv2D(64, (1, 1), padding='same')(block_1_out)  # Добавляем Conv2D-маску к текущему слою и запоминаем в переменную block_1_out_mask

    x = Conv2D(64, (3, 3), strides = (2, 2), padding = 'same', activation = 'relu')(block_1_out) # Добавляем слой MaxPooling2D

    # Block 2
    x = Conv2D(128, (3, 3), padding='same', name='block2_conv1')(x)     # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x) # Добавляем слой Activation

    x = Conv2D(128, (3, 3), padding='same', name='block2_conv2')(x)     # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    block_2_out = Activation('relu')(x)                                 # Добавляем слой Activation и запоминаем в переменной block_2_out

    block_2_out_mask = Conv2D(128, (1, 1), padding='same')(block_2_out) # Добавляем Conv2D-маску к текущему слою и запоминаем в переменную block_2_out_mask
    
    x = Conv2D(128, (3, 3), strides = (2, 2), padding = 'same', activation = 'relu')(block_2_out)                                     # Добавляем слой MaxPooling2D

    # Block 3
    x = Conv2D(256, (3, 3), padding='same', name='block3_conv1')(x)     # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv2')(x)     # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv3')(x)     # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    block_3_out = Activation('relu')(x)                                 # Добавляем слой Activation и запоминаем в переменной block_3_out

    block_3_out_mask = Conv2D(256, (1, 1), padding='same')(block_3_out) # Добавляем Conv2D-маску к текущему слою и запоминаем в переменную block_3_out_mask
        
    x = Conv2D(256, (3, 3), strides = (2, 2), padding = 'same', activation = 'relu')(block_3_out)                                     # Добавляем слой MaxPooling2D

     # Block 4
    x = Conv2D(512, (3, 3), padding='same', name='block4_conv1')(x)     # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv2')(x)     # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv3')(x)     # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    block_4_out = Activation('relu')(x)                                 # Добавляем слой Activation и запоминаем в переменной block_4_out

    block_4_out_mask = Conv2D(512, (1, 1), padding='same')(block_4_out) # Добавляем Conv2D-маску к текущему слою и запоминаем в переменную block_4_out_mask
            
    x = Conv2D(512, (3, 3), strides = (2, 2), padding = 'same', activation = 'relu')(block_4_out)                                     # Добавляем слой MaxPooling2D

    # Block 5
    x = Conv2D(512, (3, 3), padding='same', name='block5_conv1')(x)     # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv2')(x)     # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv3')(x)     # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation
    
    for_pretrained_weight = Conv2D(512, (3, 3), strides = (2, 2), padding = 'same', activation = 'relu')(x)                           # Добавляем слой MaxPooling2D
 
    # UP 1
    x = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(x) # Добавляем слой Conv2DTranspose с 512 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = concatenate([x, block_4_out, block_4_out_mask])                 # Объединем текущий слой со слоем block_4_out и слоем-маской block_4_out_mask
    x = Conv2D(512, (3, 3), padding='same')(x)                          # Добавляем слой Conv2D с 512 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same')(x)                          # Добавляем слой Conv2D с 512 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    # UP 2
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x) # Добавляем слой Conv2DTranspose с 256 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = concatenate([x, block_3_out, block_3_out_mask])                 # Объединем текущий слой со слоем block_3_out и слоем-маской block_3_out_mask
    x = Conv2D(256, (3, 3), padding='same')(x)                          # Добавляем слой Conv2D с 256 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same')(x)                          # Добавляем слой Conv2D с 256 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    # UP 3
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x) # Добавляем слой Conv2DTranspose с 128 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = concatenate([x, block_2_out, block_2_out_mask])                 # Объединем текущий слой со слоем block_2_out и слоем-маской block_2_out_mask
    x = Conv2D(128, (3, 3), padding='same')(x)                          # Добавляем слой Conv2D с 128 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    x = Conv2D(128, (3, 3), padding='same')(x)                          # Добавляем слой Conv2D с 128 нейронами
    x = BatchNormalization()(x)                                         # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                           # Добавляем слой Activation

    # UP 4
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x) # Добавляем слой Conv2DTranspose с 64 нейронами
    x = BatchNormalization()(x)                                        # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                          # Добавляем слой Activation

    x = concatenate([x, block_1_out, block_1_out_mask])                # Объединем текущий слой со слоем block_1_out и слоем-маской block_1_out_mask
    x = Conv2D(64, (3, 3), padding='same')(x)                          # Добавляем слой Conv2D с 128 нейронами
    x = BatchNormalization()(x)                                        # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                          # Добавляем слой Activation

    x = Conv2D(64, (3, 3), padding='same')(x)                          # Добавляем слой Conv2D с 128 нейронами
    x = BatchNormalization()(x)                                        # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                          # Добавляем слой Activation

    x = Conv2D(num_classes, (3, 3), activation='softmax', padding='same')(x) # Добавляем Conv2D-Слой с softmax-активацией на num_classes-нейронов

    model = Model(img_input, x)                                        # Создаем модель с входом 'img_input' и выходом 'x'

    # Компилируем модель 
    model.compile(optimizer=Adam(lr = 0.0001),
                  loss='categorical_crossentropy',
                  metrics=[dice_coef])
    
    return model                                                       # Возвращаем сформированную модель

# %%
modelM3 = unetWithMask(num_classes, (img_width, img_height, 3))

# %%
def predict_image(img_path, model):
  img = np.array(Image.open(img_path))
  width = 512
  height = 768
  input_img = cv.resize(img, (height, width), interpolation = cv.INTER_NEAREST)
  actual_img = cv.resize(img, (height * 2, width * 2), interpolation = cv.INTER_NEAREST)

  input_img = np.expand_dims(input_img, axis = 0)
  pred_image = model.predict(input_img).reshape((width, height, num_classes))
  
  pred = index2color(pred_image, actual_img, color = (255, 255, 255), final_mode = True).astype(np.uint8)
  pred = Image.fromarray(pred)
  return pred

# %%
#Загружаем лучшую модель
best_model = tf.keras.models.load_model('/content/drive/My Drive/segmentation/weightsUS/acc09811.h5')
best_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 768, 512, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 768, 512, 64) 1792        input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 768, 512, 64) 256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 768, 512, 64) 0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 768, 512, 64) 36928       activation_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 768, 512, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 768, 512, 64) 0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 384, 256, 64) 36928       activation_216[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 384, 256, 128 73856       conv2d_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 384, 256, 128 512         block2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 384, 256, 128 0           batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 384, 256, 128 147584      activation_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 384, 256, 128 512         block2_conv2[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 384, 256, 128 0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 192, 128, 128 147584      activation_218[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 192, 128, 192 221376      conv2d_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 192, 128, 192 768         block3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 192, 128, 192 0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 192, 128, 192 331968      activation_219[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 192, 128, 192 768         block3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 192, 128, 192 0           batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 192, 128, 192 331968      activation_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 192, 128, 192 768         block3_conv3[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 192, 128, 192 0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 96, 64, 256)  442624      activation_221[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 96, 64, 256)  590080      conv2d_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 96, 64, 256)  1024        block4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 96, 64, 256)  0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 96, 64, 256)  590080      activation_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 96, 64, 256)  1024        block4_conv2[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 96, 64, 256)  0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 96, 64, 256)  590080      activation_223[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 96, 64, 256)  1024        block4_conv3[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 96, 64, 256)  0           batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 48, 32, 384)  885120      activation_224[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 48, 32, 384)  1327488     conv2d_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 48, 32, 384)  1536        block5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 48, 32, 384)  0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 48, 32, 384)  1327488     activation_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 48, 32, 384)  1536        block5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 48, 32, 384)  0           batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 48, 32, 384)  1327488     activation_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 48, 32, 384)  1536        block5_conv3[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 48, 32, 384)  0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 24, 16, 512)  1769984     activation_227[0][0]
# __________________________________________________________________________________________________
# block6_conv1 (Conv2D)           (None, 24, 16, 512)  2359808     conv2d_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 24, 16, 512)  2048        block6_conv1[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 24, 16, 512)  0           batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# block6_conv2 (Conv2D)           (None, 24, 16, 512)  2359808     activation_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 24, 16, 512)  2048        block6_conv2[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 24, 16, 512)  0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# block6_conv3 (Conv2D)           (None, 24, 16, 512)  2359808     activation_229[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 24, 16, 512)  2048        block6_conv3[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 24, 16, 512)  0           batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 12, 8, 512)   2359808     activation_230[0][0]
# __________________________________________________________________________________________________
# block7_conv1 (Conv2D)           (None, 12, 8, 768)   3539712     conv2d_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 12, 8, 768)   3072        block7_conv1[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 12, 8, 768)   0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# block7_conv2 (Conv2D)           (None, 12, 8, 768)   5309184     activation_231[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 12, 8, 768)   3072        block7_conv2[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 12, 8, 768)   0           batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# block7_conv3 (Conv2D)           (None, 12, 8, 768)   5309184     activation_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 12, 8, 768)   3072        block7_conv3[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 12, 8, 768)   0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 6, 4, 768)    5309184     activation_233[0][0]
# __________________________________________________________________________________________________
# block8_conv1 (Conv2D)           (None, 6, 4, 768)    5309184     conv2d_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 6, 4, 768)    3072        block8_conv1[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 6, 4, 768)    0           batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# block8_conv2 (Conv2D)           (None, 6, 4, 768)    5309184     activation_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 6, 4, 768)    3072        block8_conv2[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 6, 4, 768)    0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# block8_conv3 (Conv2D)           (None, 6, 4, 768)    5309184     activation_235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 6, 4, 768)    3072        block8_conv3[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 6, 4, 768)    0           batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 6, 4, 768)    590592      activation_236[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_35 (Conv2DTran (None, 12, 8, 768)   2360064     conv2d_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 12, 8, 768)   3072        conv2d_transpose_35[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 12, 8, 768)   0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 12, 8, 512)   393728      activation_233[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 12, 8, 2048)  0           activation_237[0][0]
#                                                                  activation_233[0][0]
#                                                                  conv2d_162[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 12, 8, 768)   14156544    concatenate_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 12, 8, 768)   3072        conv2d_165[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 12, 8, 768)   0           batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 12, 8, 768)   5309184     activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 12, 8, 768)   3072        conv2d_166[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 12, 8, 768)   0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_36 (Conv2DTran (None, 24, 16, 512)  1573376     activation_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 24, 16, 512)  2048        conv2d_transpose_36[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 24, 16, 512)  0           batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 24, 16, 512)  262656      activation_230[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 24, 16, 1536) 0           activation_240[0][0]
#                                                                  activation_230[0][0]
#                                                                  conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 24, 16, 512)  7078400     concatenate_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 24, 16, 512)  2048        conv2d_167[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 24, 16, 512)  0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 24, 16, 512)  2359808     activation_241[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 24, 16, 512)  2048        conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 24, 16, 512)  0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_37 (Conv2DTran (None, 48, 32, 384)  786816      activation_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 48, 32, 384)  1536        conv2d_transpose_37[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 48, 32, 384)  0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 48, 32, 384)  147840      activation_227[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 48, 32, 1152) 0           activation_243[0][0]
#                                                                  activation_227[0][0]
#                                                                  conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 48, 32, 384)  3981696     concatenate_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 48, 32, 384)  1536        conv2d_169[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 48, 32, 384)  0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 48, 32, 384)  1327488     activation_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 48, 32, 384)  1536        conv2d_170[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 48, 32, 384)  0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_38 (Conv2DTran (None, 96, 64, 256)  393472      activation_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 96, 64, 256)  1024        conv2d_transpose_38[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 96, 64, 256)  0           batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 96, 64, 384)  98688       activation_224[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 96, 64, 896)  0           activation_246[0][0]
#                                                                  activation_224[0][0]
#                                                                  conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 96, 64, 256)  2064640     concatenate_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 96, 64, 256)  1024        conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 96, 64, 256)  0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 96, 64, 256)  590080      activation_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 96, 64, 256)  1024        conv2d_172[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 96, 64, 256)  0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_39 (Conv2DTran (None, 192, 128, 192 196800      activation_248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 192, 128, 192 768         conv2d_transpose_39[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 192, 128, 192 0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 192, 128, 192 37056       activation_221[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 192, 128, 576 0           activation_249[0][0]
#                                                                  activation_221[0][0]
#                                                                  conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 192, 128, 192 995520      concatenate_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 192, 128, 192 768         conv2d_173[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 192, 128, 192 0           batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 192, 128, 192 331968      activation_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 192, 128, 192 768         conv2d_174[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 192, 128, 192 0           batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_40 (Conv2DTran (None, 384, 256, 128 98432       activation_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 384, 256, 128 512         conv2d_transpose_40[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 384, 256, 128 0           batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 384, 256, 128 16512       activation_218[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 384, 256, 384 0           activation_252[0][0]
#                                                                  activation_218[0][0]
#                                                                  conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 384, 256, 128 442496      concatenate_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 384, 256, 128 512         conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 384, 256, 128 0           batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 384, 256, 128 147584      activation_253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 384, 256, 128 512         conv2d_176[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 384, 256, 128 0           batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_41 (Conv2DTran (None, 768, 512, 64) 32832       activation_254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 768, 512, 64) 256         conv2d_transpose_41[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 768, 512, 64) 0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 768, 512, 64) 4160        activation_216[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 768, 512, 192 0           activation_255[0][0]
#                                                                  activation_216[0][0]
#                                                                  conv2d_150[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 768, 512, 64) 110656      concatenate_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 768, 512, 64) 256         conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 768, 512, 64) 0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 768, 512, 64) 36928       activation_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 768, 512, 64) 256         conv2d_178[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 768, 512, 64) 0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 768, 512, 2)  1154        activation_257[0][0]
# ==================================================================================================
# Total params: 101,005,378
# Trainable params: 100,973,506
# Non-trainable params: 31,872
# __________________________________________________________________________________________________

# %%
predict_image(directory + 'orig/дог200.jpg', model = best_model)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
